# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import ast

# %%
games_genre = pd.read_csv('/content/drive/MyDrive/DS5230_Project/top_100_games_genre.csv')

games_genre.head()
# Out:
#             game_name                                              genre
# 0       Just Chatting                ['Indie', 'Simulator', 'Adventure']
# 1   League of Legends         ['Role-playing (RPG)', 'Strategy', 'MOBA']
# 2  Grand Theft Auto V  ['Shooter', 'Role-playing (RPG)', 'Adventure',...
# 3            Fortnite                                        ['Shooter']
# 4              Sports                                          ['Sport']

# %%
games_genre["genre"][0]
# Out:
# "['Indie', 'Simulator', 'Adventure']"

# %%
# Convert string representations of lists back to actual lists
df['genre'] = games_genre['genre'].apply(ast.literal_eval)

# Now apply pd.Series to expand the lists
expanded_df = df['genre'].apply(pd.Series)

# %%
expanded_df.head()
# Out:
#                     0                   1          2  \
# 0               Indie           Simulator  Adventure
# 1  Role-playing (RPG)            Strategy       MOBA
# 2             Shooter  Role-playing (RPG)  Adventure
# 3             Shooter                 NaN        NaN
# 4               Sport                 NaN        NaN
#
#                             3    4    5
# 0                         NaN  NaN  NaN
# 1                         NaN  NaN  NaN
# 2  Hack and slash/Beat 'em up  NaN  NaN
# 3                         NaN  NaN  NaN
# 4                         NaN  NaN  NaN

# %%
genre = expanded_df.merge(games_genre, left_index = True, right_index = True).drop(["genre"], axis = 1)

# %%
genres = expanded_df.merge(games_genre, right_index = True, left_index = True).drop(["genre"], axis = 1).melt(id_vars = ['game_name'], value_name = "genre").drop("variable", axis = 1).dropna()

# %%
genres.rename(columns = {"genre": "game_genres"}, inplace = True)

# %%
genres.to_csv(r'/content/drive/MyDrive/DS5230_Project/top_100_games_genres.csv', index = False)
